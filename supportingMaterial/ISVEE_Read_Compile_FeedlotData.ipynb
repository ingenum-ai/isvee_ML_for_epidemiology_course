# %% [markdown]
# <a href="https://colab.research.google.com/github/ingenum-ai/ISVEE_deepLearning_2024/blob/main/supportingMaterial/ISVEE_Read_Compile_FeedlotData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Read in and compile
#
# Ausvet Feedlot dataset converted to python dataframe for Py tensors

# %%
# Load the Drive helper, mount and prompt for authorization.
from google.colab import drive
drive.mount('/content/drive')
# !pip install itables
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.8 MB/s eta 0:00:00
# ...

# %%
import os
import re
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option("display.precision", 2)
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
from datetime import datetime
from google.colab import data_table
from itables import init_notebook_mode, show

# %%
# Read in table from source

df1 = pd.read_csv('/content/drive/Shareddrives/ingenum_operations/5_Current_Projects/23_07_ISVEE_PreConf_workshop/3_Data/Ausvet_feedlot_dataset.csv',  encoding='latin-1')

# Deal with NaN values

df1.dropna(axis=1, how='all', inplace=True)

df1 = df1.fillna(pd.NA)
df1 = df1.replace({pd.NA: np.nan})

df1.columns = df1.columns.str.strip()
# Out:
# <ipython-input-3-238aa97170cc>:3: DtypeWarning: Columns (5,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/drive/Shareddrives/ingenum_operations/5_Current_Projects/23_07_ISVEE_PreConf_workshop/3_Data/Ausvet_feedlot_dataset.csv',  encoding='latin-1')

# %% [markdown]
# #Munge

# %%
# Initialise munge with commands across all fields

# %%
init_notebook_mode(all_interactive=True)
def subset_and_display(df, start_col, end_col):
  """Subsets a DataFrame to the specified column range and displays it."""
  show(df.iloc[:, start_col:end_col])

# First 20 columns
subset_and_display(df1, 0, 20)
# Remaining columns (from column 20 onwards)
subset_and_display(df1, 20, len(df1.columns))

data_table.enable_dataframe_formatter()
#df1

df1.describe(include='all')
# Out:
# <script>
#     let is_dark_theme = function () {
#         // Jupyter Lab
#         if ('jpThemeLight' in document.body.dataset)
#             return (document.body.dataset.jpThemeLight === "false");
#
#         // VS Code
#         if ('vscodeThemeKind' in document.body.dataset)
#             return document.body.dataset.vscodeThemeKind.includes('dark');
#
#         // Jupyter Book
#         if ('theme' in document.documentElement.dataset)
#             return document.documentElement.dataset.theme.includes('dark');
#
#         // Default
#         return window.matchMedia('(prefers-color-scheme: dark)').matches;
#     }
#
#     if (is_dark_theme()) {
#         document.documentElement.classList.add('dark');
#     }
#     else {
#         document.documentElement.classList.remove('dark');
#     }
# </script>
# ...

# %% [markdown]
# #Outcome variable
# buller2

# %%
# Convert outcome variable buller2

# %% [markdown]
# ##Predictor variables
#
# Variables of interest:
# - Induction weight
# - induction month
# - induction season
# - treatment protocol

# %%
# Process predictor variables

# %% [markdown]
# ##Export csv (or pickle if required)

# %%
# Create subset dataset for tensors

subset_columns = ['buller2', 'ind_weight', 'ind_month', 'ind_season', 'treatment_protocol']
feedlot_tensor_df = df1[subset_columns]
feedlot_tensor_df.to_csv('/content/drive/My Drive/feedlot_tensor.csv', index=False)
